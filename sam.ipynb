# %%
from pathlib import Path
import time

from tqdm import tqdm

from src.pipeline import img_pipeline
from src.detection import RoboflowDetector
from src.segmentation import SAMSegmenter

# %%
ROBOFLOW_API_KEY = "KDf14v839AjRzJXanN4h"
ROBOFLOW_MODEL_ID = "raspberrypi_redball/2"
SAM_MODEL_NAME = "sam2.1_b.pt"

detector = RoboflowDetector(model_id=ROBOFLOW_MODEL_ID, api_key=ROBOFLOW_API_KEY)
segmenter = SAMSegmenter(model_name=SAM_MODEL_NAME)

# %%
imgs_path = Path("df")
assert imgs_path.exists(), f"Folder '{imgs_path}' not found"
img_paths = list(imgs_path.glob("*"))

# %%
DET_OUTPUT = Path("detection_output_folder")
SAM_OUTPUT = Path("sam_output_folder")

start_time = time.time()

for img_path in tqdm(img_paths):
    img_pipeline(
        img_path,
        detect_fn=detector.detect,
        segment_fn=segmenter.segment,
        det_output_dir=DET_OUTPUT,
        seg_output_dir=SAM_OUTPUT,
    )

duration = time.time() - start_time
print(f"Done in {duration:.2f}s ({duration / len(img_paths):.2f}s/img)")
# Out:
#  44%|████▍     | 7/16 [01:08<01:28,  9.83s/it]
#  44%|████▍     | 7/16 [01:08<01:28,  9.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 7
#       4 start_time = time.time()
#       6 for img_path in tqdm(img_paths):
# ----> 7     img_pipeline(
#       8         img_path,
#       9         detect_fn=detector.detect,
#      10         segment_fn=segmenter.segment,
#      11         det_output_dir=DET_OUTPUT,
#      12         seg_output_dir=SAM_OUTPUT,
#      13     )
#      15 duration = time.time() - start_time
#      16 print(f"Done in {duration:.2f}s ({duration / len(img_paths):.2f}s/img)")
#
# File c:\Users\antoi\Desktop\projets IA\yolo11seg\src\pipeline.py:48, in img_pipeline(img_path, detect_fn, segment_fn, det_output_dir, seg_output_dir)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\antoi\Desktop\projets IA\yolo11seg\src\segmentation.py:44, in segment(self, img_path, bbox)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\model.py:128, in SAM.__call__(self, source, stream, bboxes, points, labels, **kwargs)
#     105 def __call__(self, source=None, stream: bool = False, bboxes=None, points=None, labels=None, **kwargs):
#     106     """Perform segmentation prediction on the given image or video source.
#     107
#     108     This method is an alias for the 'predict' method, providing a convenient way to call the SAM model for
#    (...)    126         >>> print(f"Detected {len(results[0].masks)} masks")
#     127     """
# --> 128     return self.predict(source, stream, bboxes, points, labels, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\model.py:103, in SAM.predict(self, source, stream, bboxes, points, labels, **kwargs)
#     101 kwargs = {**overrides, **kwargs}
#     102 prompts = dict(bboxes=bboxes, points=points, labels=labels)
# --> 103 return super().predict(source, stream, prompts=prompts, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\engine\model.py:535, in Model.predict(self, source, stream, predictor, **kwargs)
#     533 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     534     self.predictor.set_prompts(prompts)
# --> 535 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\engine\predictor.py:328, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     326 # Inference
#     327 with profilers[1]:
# --> 328     preds = self.inference(im, *args, **kwargs)
#     329     if self.args.embed:
#     330         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\predict.py:198, in Predictor.inference(self, im, bboxes, points, labels, masks, multimask_output, *args, **kwargs)
#     195 if all(i is None for i in [bboxes, points, masks]):
#     196     return self.generate(im, *args, **kwargs)
# --> 198 return self.prompt_inference(im, bboxes, points, labels, masks, multimask_output)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\predict.py:229, in Predictor.prompt_inference(self, im, bboxes, points, labels, masks, multimask_output)
#     226 features = self.get_im_features(im) if self.features is None else self.features
#     228 prompts = self._prepare_prompts(im.shape[2:], self.batch[1][0].shape[:2], bboxes, points, labels, masks)
# --> 229 return self._inference_features(features, *prompts, multimask_output)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\predict.py:856, in SAM2Predictor._inference_features(self, features, points, labels, masks, multimask_output, img_idx)
#     854     high_res_features = [feat_level[img_idx].unsqueeze(0) for feat_level in features["high_res_feats"]]
#     855     features = features["image_embed"][[img_idx]]
# --> 856 pred_masks, pred_scores, _, _ = self.model.sam_mask_decoder(
#     857     image_embeddings=features,
#     858     image_pe=self.model.sam_prompt_encoder.get_dense_pe(),
#     859     sparse_prompt_embeddings=sparse_embeddings,
#     860     dense_prompt_embeddings=dense_embeddings,
#     861     multimask_output=multimask_output,
#     862     repeat_image=batched_mode,
#     863     high_res_features=high_res_features,
#     864 )
#     865 # (N, d, H, W) --> (N*d, H, W), (N, d) --> (N*d, )
#     866 # `d` could be 1 or 3 depends on `multimask_output`.
#     867 return pred_masks.flatten(0, 1), pred_scores.flatten(0, 1)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\modules\decoders.py:334, in SAM2MaskDecoder.forward(self, image_embeddings, image_pe, sparse_prompt_embeddings, dense_prompt_embeddings, multimask_output, repeat_image, high_res_features)
#     297 def forward(
#     298     self,
#     299     image_embeddings: torch.Tensor,
#    (...)    305     high_res_features: list[torch.Tensor] | None = None,
#     306 ) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
#     307     """Predict masks given image and prompt embeddings.
#     308
#     309     Args:
#    (...)    332         ... )
#     333     """
# --> 334     masks, iou_pred, mask_tokens_out, object_score_logits = self.predict_masks(
#     335         image_embeddings=image_embeddings,
#     336         image_pe=image_pe,
#     337         sparse_prompt_embeddings=sparse_prompt_embeddings,
#     338         dense_prompt_embeddings=dense_prompt_embeddings,
#     339         repeat_image=repeat_image,
#     340         high_res_features=high_res_features,
#     341     )
#     343     # Select the correct mask or masks for output
#     344     if multimask_output:
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\modules\decoders.py:404, in SAM2MaskDecoder.predict_masks(self, image_embeddings, image_pe, sparse_prompt_embeddings, dense_prompt_embeddings, repeat_image, high_res_features)
#     401 b, c, h, w = src.shape
#     403 # Run the transformer
# --> 404 hs, src = self.transformer(src, pos_src, tokens)
#     405 iou_token_out = hs[:, s, :]
#     406 mask_tokens_out = hs[:, s + 1 : (s + 1 + self.num_mask_tokens), :]
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\modules\transformer.py:108, in TwoWayTransformer.forward(self, image_embedding, image_pe, point_embedding)
#     106 # Apply transformer blocks and final layernorm
#     107 for layer in self.layers:
# --> 108     queries, keys = layer(
#     109         queries=queries,
#     110         keys=keys,
#     111         query_pe=point_embedding,
#     112         key_pe=image_pe,
#     113     )
#     115 # Apply the final attention layer from the points to the image
#     116 q = queries + point_embedding
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\modules\transformer.py:214, in TwoWayAttentionBlock.forward(self, queries, keys, query_pe, key_pe)
#     212 else:
#     213     q = queries + query_pe
# --> 214     attn_out = self.self_attn(q=q, k=q, v=queries)
#     215     queries = queries + attn_out
#     216 queries = self.norm1(queries)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\ultralytics\models\sam\modules\transformer.py:344, in Attention.forward(self, q, k, v)
#     342 out = attn @ v
#     343 out = self._recombine_heads(out)
# --> 344 return self.out_proj(out)
#
# File c:\Users\antoi\Desktop\projets IA\.venv\Lib\site-packages\torch\nn\modules\module.py:1951, in Module.__getattr__(self, name)
#    1946         self._backward_pre_hooks = OrderedDict()
#    1948 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1949 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1950 # https://github.com/pytorch/pytorch/pull/115074
# -> 1951 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1952     if "_parameters" in self.__dict__:
#    1953         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
